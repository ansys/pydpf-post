# %% [markdown]
# #### Starts post service

# %%
from ansys.dpf import post
# Out:
# server started at --address 10.110.2.65 --port 50052

# %% [markdown]
# #### solution object and its properties

# %%
solution = post.load_solution("d:/rst/twobodies.rst")

# %%
mesh = solution.mesh

# %%
time_freq_support = solution.time_freq_support

# %% [markdown]
# #### result object (stress)

# %%
stress = solution.stress(location=post.locations.elemental, time_scoping=[1])

# %% [markdown]
# #### data wrapper

# %%
sx = stress.xx
s2 = stress.principal_2
s = stress.tensor

# %%
sx.max_data
# Out:
# array([3.38161987e+12])

# %%
s2.num_fields
# Out:
# 2

# %%
s.get_data_at_field(0) #equivalent to s[0].data
# Out:
# array([[-2.81019946e+12, -6.48149756e+11, -6.40452549e+12,
#          6.27870832e+10, -4.61583344e+11, -1.08277702e+11],
#        [ 0.00000000e+00, -2.61120000e+04,  3.27680000e+04,
#          1.19071083e+11, -2.13019230e+11, -5.37600000e+03],
#        [ 2.81019938e+12,  6.48149774e+11,  6.40452547e+12,
#          6.27870861e+10, -4.61583327e+11,  1.08277697e+11],
#        ...,
#        [ 5.80155301e+10,  3.69072931e+11, -2.16180572e+12,
#         -3.66684317e+11, -1.20689543e+12,  1.66195492e+11],
#        [-5.80157593e+10, -3.69073015e+11,  2.16180569e+12,
#         -3.66684431e+11, -1.20689551e+12, -1.66195449e+11],
#        [-7.02016324e+11, -1.19689480e+12,  5.73811820e+12,
#         -1.02828495e+11, -5.18707118e+10, -7.50258529e+11]])

# %%
s.plot_contour("time", 1)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x26511E0FAC8>

# %% [markdown]
# #### result object (displacement)

# %%
disp = solution.displacement()

# %%
d = disp.vector

# %%
d.plot_contour()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x26511D95648>
